# %% [markdown]
# # Keseluruhan Code

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
#Import Library untuk Tokenisasi
import string 
import re #regex library

# import word_tokenize & FreqDist dari NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# import the dataset from sklearn
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA


# viz libs
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Data PTA

# %%
dataPTA = pd.read_csv('ta-manajemen.csv')

# %%
dataPTA.head(10)
# Out:
#                                                judul  \
# 0  PENGARUH KEPEMIMPINAN DAN KOMPENSASI TERHADAP ...
# 1  Pengukuran Website Quality Pada Situs Sistem A...
# 2  ANALISIS PERSEPSI BRAND ASSOCIATION MENURUT PE...
# 3  analisis faktor-faktor yang berpengaruh terhad...
# 4  PENGARUH FAKTOR-FAKTOR PELATIHAN DAN PENGEMBAN...
# 5  ANALISIS TINGKAT RISIKO KREDIT \r\nPADA PD. BP...
# 6  Pengaruh Harga dan Kualitas Pelayanan terhadap...
# 7  ANALISIS CONSUMER DECISION MODEL (CDM) UNTUK M...
# 8  PENGARUH TIPE KEPEMIMPINAN TERHADAP PRESTASI K...
# 9  PENGARUH CELEBRITY ENDORSER IWAN FALS TERHADAP...
#
#                              penulis  \
# 0  Penulis : Hendri Wahyudi Prayitno
# 1   Penulis : Muhammad Zakaria Utomo
# 2                  Penulis : Faishal
# 3                  Penulis : Jailani
# 4                  Penulis : SATIYAH
# 5     Penulis : Iwan Kurniawan Gomes
# 6              Penulis : ALI RAHBINI
# 7            Penulis : SYAIFUL ANWAR
# 8       Penulis : Dharma Abidin Syah
# 9              Penulis : Tayyi Matun
#
#                                            abstraksi
# 0  Abstrak\r\nPenelitian ini menggunakan metode k...
# 1  Aplikasi nyata pemanfaatan teknologi informasi...
# 2  Tujuan penelitian ini adalah untuk mengetahui ...
# 3  ABSTRAK\r\nTujuan penelitian ini adalah untuk ...
# 4  ABSTRAK\r\nSatiyah, Pengaruh Faktor-faktor Pel...
# 5  Hasil dari penelitian ini dari perhitungan Cre...
# 6  Ali Rahbini, Pengaruh Harga dan Kualitas Pelay...
# 7  ABSTRAK\r\n\r\nPenelitian ini bertujuan untuk ...
# 8  ABSTRAK\r\n\tDharma Abidin Syah,Kesimpulan: (1...
# 9  Tujuan penelitian ini adalah mengetahui pengar...

# %% [markdown]
# # Case Folding

# %%
# gunakan fungsi Series.str.lower() pada Pandas
dataPTA['abstraksi'] = dataPTA['abstraksi'].str.lower()

print('Case Folding Result : \n')

#cek hasil case fold
print(dataPTA['abstraksi'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0    abstrak\r\npenelitian ini menggunakan metode k...
# 1    aplikasi nyata pemanfaatan teknologi informasi...
# 2    tujuan penelitian ini adalah untuk mengetahui ...
# 3    abstrak\r\ntujuan penelitian ini adalah untuk ...
# 4    abstrak\r\nsatiyah, pengaruh faktor-faktor pel...
# Name: abstraksi, dtype: object

# %% [markdown]
# # Removal

# %%
#Import Library untuk Tokenisasi
import string 
import re #regex library

# import word_tokenize & FreqDist dari NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

def remove_PTA_special(text):
    # menghapus tab, new line, dan back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
dataPTA['abstraksi'] = dataPTA['abstraksi'].apply(remove_PTA_special)

#menghapus nomor
def remove_number(text):
    return  re.sub(r"\d+", "", text)

dataPTA['abstraksi'] = dataPTA['abstraksi'].apply(remove_number)

#menghapus punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

dataPTA['abstraksi'] = dataPTA['abstraksi'].apply(remove_punctuation)

#menghapus spasi leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

dataPTA['abstraksi'] = dataPTA['abstraksi'].apply(remove_whitespace_LT)

#menghapus spasi tunggal dan ganda
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

dataPTA['abstraksi'] = dataPTA['abstraksi'].apply(remove_whitespace_multiple)

# menghapus kata 1 abjad
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

dataPTA['abstraksi'] = dataPTA['abstraksi'].apply(remove_singl_char)

# Tokenisasi
def word_tokenize_wrapper(text):
    return word_tokenize(text)

dataPTA['abstrak_token'] = dataPTA['abstraksi'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(dataPTA['abstrak_token'].head())
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0    [abstrak, penelitian, ini, menggunakan, metode...
# 1    [aplikasi, nyata, pemanfaatan, teknologi, info...
# 2    [tujuan, penelitian, ini, adalah, untuk, menge...
# 3    [abstrak, tujuan, penelitian, ini, adalah, unt...
# 4    [abstrak, satiyah, pengaruh, faktorfaktor, pel...
# Name: abstrak_token, dtype: object

# %% [markdown]
# # STOPWORD

# %%
from nltk.corpus import stopwords

list_stopwords = stopwords.words('indonesian')

# Mengubah List ke dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

#aStopwording
dataPTA['abstrak_stop'] = dataPTA['abstrak_token'].apply(stopwords_removal) 


print(dataPTA['abstrak_stop'].head(20))
# Out:
# 0     [abstrak, penelitian, metode, kuantitatif, men...
# 1     [aplikasi, nyata, pemanfaatan, teknologi, info...
# 2     [tujuan, penelitian, persepsi, brand, associat...
# 3     [abstrak, tujuan, penelitian, pengaruh, variab...
# 4     [abstrak, satiyah, pengaruh, faktorfaktor, pel...
# 5     [hasil, penelitian, perhitungan, credit, risk,...
# 6     [ali, rahbini, pengaruh, harga, kualitas, pela...
# 7     [abstrak, penelitian, bertujuan, mengukur, efe...
# 8     [abstrak, dharma, abidin, syahkesimpulan, peng...
# 9     [tujuan, penelitian, pengaruh, celebrity, endo...
# 10    [tujuan, penelitian, mengidentifikasi, variabe...
# 11    [pln, badan, usaha, milik, negara, bergerak, b...
# 12    [abstrak, tujuan, penelitian, mengidentifikasi...
# 13    [abstrak, haryono, arifin, pengaruh, perilaku,...
# 14    [bauran, eceran, salah, langkah, pemasaran, ke...
# 15    [abstrak, aththaariq, pengaruh, kompetensi, do...
# 16    [abstrak, tujuan, penelitian, mendeskripsikan,...
# 17    [abstrak, penelitian, rumusan, pelaporan, biay...
# 18    [tujuan, penelitian, pengaruh, variabel, retai...
# Name: abstrak_stop, dtype: object

# %%
dataPTA.head()
# Out:
#                                                judul  \
# 0  PENGARUH KEPEMIMPINAN DAN KOMPENSASI TERHADAP ...
# 1  Pengukuran Website Quality Pada Situs Sistem A...
# 2  ANALISIS PERSEPSI BRAND ASSOCIATION MENURUT PE...
# 3  analisis faktor-faktor yang berpengaruh terhad...
# 4  PENGARUH FAKTOR-FAKTOR PELATIHAN DAN PENGEMBAN...
#
#                              penulis  \
# 0  Penulis : Hendri Wahyudi Prayitno
# 1   Penulis : Muhammad Zakaria Utomo
# 2                  Penulis : Faishal
# 3                  Penulis : Jailani
# 4                  Penulis : SATIYAH
#
#                                            abstraksi  \
# 0  abstrak penelitian ini menggunakan metode kuan...
# 1  aplikasi nyata pemanfaatan teknologi informasi...
# 2  tujuan penelitian ini adalah untuk mengetahui ...
# 3  abstrak tujuan penelitian ini adalah untuk men...
# 4  abstrak satiyah pengaruh faktorfaktor pelatiha...
#
#                                        abstrak_token  \
# 0  [abstrak, penelitian, ini, menggunakan, metode...
# 1  [aplikasi, nyata, pemanfaatan, teknologi, info...
# 2  [tujuan, penelitian, ini, adalah, untuk, menge...
# 3  [abstrak, tujuan, penelitian, ini, adalah, unt...
# 4  [abstrak, satiyah, pengaruh, faktorfaktor, pel...
#
#                                         abstrak_stop  \
# 0  [abstrak, penelitian, metode, kuantitatif, men...
# 1  [aplikasi, nyata, pemanfaatan, teknologi, info...
# 2  [tujuan, penelitian, persepsi, brand, associat...
# 3  [abstrak, tujuan, penelitian, pengaruh, variab...
# 4  [abstrak, satiyah, pengaruh, faktorfaktor, pel...
#
#                                         abstrak_stem   cluster        x0  \
# 0  [abstrak, teliti, metode, kuantitatif, tekan, ...      tech  0.381423
# 1  [aplikasi, nyata, manfaat, teknologi, informas...  religion -0.372050
# 2  [tuju, teliti, persepsi, brand, association, l...  religion -0.356188
# 3  [abstrak, tuju, teliti, pengaruh, variabel, cu...  religion -0.030234
# 4  [abstrak, satiyah, pengaruh, faktorfaktor, lat...      tech  0.139304
#
#          x1
# 0  0.269279
# 1  0.213274
# 2 -0.158817
# 3  0.108835
# 4 -0.114255

# %% [markdown]
# # stemming

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# membuat stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# sfungsi stemmer
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in dataPTA['abstrak_stop']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# stemming pada dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

dataPTA['abstrak_stem'] = dataPTA['abstrak_stop'].swifter.apply(get_stemmed_term)
print(dataPTA['abstrak_stem'])
# Out:
# 576
# ------------------------
# abstrak : abstrak
# penelitian : teliti
# metode : metode
# kuantitatif : kuantitatif
# menekankan : tekan
# pengujian : uji
# hipotesis : hipotesis
# variabel : variabel
# kepemimpinanx : kepemimpinanx
# kompensasi : kompensasi
# dilaksanakan : laksana
# kantor : kantor
# dinas : dinas
# pendidikan : didik
# kabupaten : kabupaten
# sampang : sampang
# sampel : sampel
# orang : orang
# pegawai : pegawai
# negeri : negeri
# sipil : sipil
# non : non
# pns : pns
# bebas : bebas
# bersamasama : bersamasama
# hubungan : hubung
# signifikan : signifikan
# simultan : simultan
# kepemimpinan : pimpin
# kinerja : kerja
# terbukti : bukti
# nilai : nilai
# fhitung : fhitung
# tingkat : tingkat
# pengaruh : pengaruh
# dominan : dominan
# hitung : hitung
# positif : positif
# parsial : parsial
# terikat : ikat
# kesimpulan : simpul
# berdasarkan : dasar
# statistik : statistik
# memiliki : milik
# membuktikan : bukti
# berpengaruh : pengaruh
# kunci : kunci
# aplikasi : aplikasi
# nyata : nyata
# pemanfaatan : manfaat
# teknologi : teknologi
# informasi : informasi
# komunikasi : komunikasi
# bidang : bidang
# layanan : layan
# administrasi : administrasi
# akademik : akademik
# perguruan : guru
# salah : salah
# satunya : satu
# sistem : sistem
# portal : portal
# universitas : universitas
# trunojoyo : trunojoyo
# madura : madura
# implementasi : implementasi
# proses : proses
# penyelenggaraannya : selenggara
# menemui : temu
# kendala : kendala
# teknis : teknis
# bertujuan : tuju
# kepuasan : puas
# pelanggan : langgan
# analisis : analisis
# indeks : indeks
# ditinjau : tinjau
# webqual : webqual
# fokus : fokus
# perbaikan : baik
# mutu : mutu
# pelayanan : layan
# website : website
# trunjoyo : trunjoyo
# importance : importance
# performance : performance
# analysis : analysis
# kuantitaif : kuantitaif
# deskriptif : deskriptif
# gambaran : gambar
# deskripsi : deskripsi
# lukisan : lukis
# sistematis : sistematis
# faktual : faktual
# akurat : akurat
# kualitas : kualitas
# jasa : jasa
# online : online
# mahasiswasampelpenelitianiniadalahmahasiswaangkatan : mahasiswasampelpenelitianiniadalahmahasiswaangkatan
# teknik : teknik
# stratified : stratified
# random : random
# sampling : sampling
# alat : alat
# kepentingan : penting
# hasil : hasil
# skor : skor
# ikp : ikp
# masuk : masuk
# kategori : kategori
# puas : puas
# diagram : diagram
# kartesius : kartesius
# atribut : atribut
# prioritas : prioritas
# utama : utama
# situs : situs
# mahasiswa : mahasiswa
# jelasdetail : jelasdetail
# ter : ter
# update : update
# ki : ki
# disitus : situs
# utm : utm
# dipercaya : percaya
# pengguna : guna
# aman : aman
# data : data
# krs : krs
# khs : khs
# transkrip : transkrip
# personal : personal
# sesuai : sesuai
# kip : kip
# tujuan : tuju
# persepsi : persepsi
# brand : brand
# association : association
# pakaian : pakai
# kiddrock : kiddrock
# studi : studi
# distro : distro
# cranberries : cranberries
# pamekasan : pamekasan
# survei : survei
# populasi : populasi
# responden : responden
# desember : desember
# pengambilan : ambil
# aksidental : aksidental
# pengumpulan : kumpul
# lapangan : lapang
# field : field
# research : research
# membagikan : bagi
# kuesioner : kuesioner
# riset : riset
# perpustakaan : pustaka
# pengolahan : olah
# pengolaha : pengolaha
# bantuan : bantu
# perangkat : perangkat
# lunak : lunak
# spss : spss
# versi : versi
# uji : uji
# validitas : validitas
# reabilitas : reabilitas
# skala : skala
# likert : likert
# konsumen : konsumen
# dimensi : dimensi
# jaminan : jamin
# identifikasi : identifikasi
# pribadi : pribadi
# sosial : sosial
# status : status
# kesediaan : sedia
# menerima : terima
# perluasan : luas
# merek : merek
# merekomendasikan : rekomendasi
# menunjukan : tunjuk
# cranberriess : cranberriess
# apresisasikan : apresisasikan
# presepsi : presepsi
# current : current
# ratio : ratio
# return : return
# on : on
# equity : equity
# firm : firm
# size : size
# leverage : leverage
# business : business
# risk : risk
# kebijakan : bijak
# deviden : deviden
# perusahaan : usaha
# manufaktur : manufaktur
# terdaftar : daftar
# bursa : bursa
# efek : efek
# indonesia : indonesia
# periode : periode
# pendekatan : dekat
# berturutturut : berturutturut
# purposive : purposive
# instrumen : instrumen
# asumsi : asumsi
# klasik : klasik
# menguji : uji
# regresi : regresi
# linier : linier
# berganda : ganda
# memakai : pakai
# square : square
# businees : businees
# dividend : dividend
# payout : payout
# satiyah : satiyah
# faktorfaktor : faktorfaktor
# pelatihan : latih
# pengembangan : kembang
# produktivitas : produktivitas
# kerja : kerja
# kelautan : laut
# perikanan : ikan
# bangkalan : bangkal
# dibawah : bawah
# bimbingan : bimbing
# drahjsanugrahini : drahjsanugrahini
# irawatimm : irawatimm
# helmi : helm
# buyung : buyung
# auliasstsemmt : auliasstsemmt
# upaya : upaya
# meningkatkan : tingkat
# mudah : mudah
# usaha : usaha
# meningkat : tingkat
# menerapkan : terap
# program : program
# sumber : sumber
# daya : daya
# manusia : manusia
# sdm : sdm
# instansi : instansi
# tercapai : capai
# kemampuan : mampu
# efektif : efektif
# efisien : efisien
# pengembnagan : pengembnagan
# diharapkan : harap
# menyesuaikan : sesuai
# kebutuhankebutuhan : kebutuhankebutuhan
# sikap : sikap
# tingkah : tingkah
# laku : laku
# keterampilan : terampil
# pengetahuan : tahu
# tuntutan : tuntut
# perubahan : ubah
# mendukung : dukung
# terciptanya : cipta
# suasana : suasana
# kondusif : kondusif
# produktivitasi : produktivitas
# mengukur : ukur
# menganalisa : menganalisa
# peneliti : teliti
# observasional : observasional
# analitik : analitik
# pengamatan : amat
# langsung : langsung
# penyebaran : sebar
# kuisioner : kuisioner
# dianalisis : analis
# diolah : olah
# probality : probality
# simple : simple
# perbedaan : beda
# individu : individu
# jabatan : jabat
# motivasi : motivasi
# partisipasi : partisipasi
# aktif : aktif
# seleksi : seleksi
# peserta : serta
# instruktur : instruktur
# koefisien : koefisien
# determinasi : determinasi
# ftabel : ftabel
# faktor : faktor
# thitung : thitung
# perhitungan : hitung
# credit : credit
# npl : npl
# pd : pd
# bpr : bpr
# bank : bank
# daerah : daerah
# lamongan : lamongan
# mengalami : alami
# penurunan : turun
# resiko : resiko
# dikatagorikan : dikatagorikan
# ketentuan : tentu
# syarat : syarat
# maksimal : maksimal
# performing : performing
# loan : loan
# ali : ali
# rahbini : rahbini
# harga : harga
# berbelanja : belanja
# swalayan : swalayan
# tom : tom
# jerry : jerry
# pribanus : pribanus
# wantara : wantara
# nirma : nirma
# kurriwati : kurriwati
# terkumpul : kumpul
# bantu : bantu
# software : software
# diperoleh : oleh
# kehandalan : kehandalan
# tanggap : tanggap
# empati : empati
# bukti : bukti
# fisik : fisik
# keandalan : andal
# efektivitas : efektivitas
# iklan : iklan
# consumer : consumer
# decision : decision
# model : model
# cdm : cdm
# jalur : jalur
# path : path
# pesan : pesan
# pengenalan : kenal
# keyakinan : yakin
# niat : niat
# beli : beli
# pembelian : beli
# dharma : dharma
# abidin : abidin
# syahkesimpulan : syahkesimpulan
# tipe : tipe
# autoritarian : autoritarian
# laissezfaire : laissezfaire
# demokratis : demokratis
# prestasi : prestasi
# kecamatan : camat
# pangarengan : pangarengan
# anova : anova
# kontribusi : kontribusi
# autoritariansecara : autoritariansecara
# pegawaidikantor : pegawaidikantor
# tabel : tabel
# laissezfairesecara : laissezfairesecara
# lainya : lai
# dikantor : kantor
# celebrity : celebrity
# endorser : endorser
# iwan : iwan
# fals : fals
# minat : minat
# produk : produk
# top : top
# coffee : coffee
# masyarakat : masyarakat
# sumur : sumur
# kembang : kembang
# kelurahan : lurah
# pejagan : pejagan
# survey : survey
# menngunakan : menngunakan
# lapang : lapang
# erangkat : erangkat
# for : for
# windows : windows
# trustworthiness : trustworthiness
# expertise : expertise
# attractiveness : attractiveness
# respect : respect
# similarity : similarity
# mempengaruhi : pengaruh
# minet : minet
# disimpulkan : simpul
# miant : miant
# mengidentifikasi : identifikasi
# variabelvariabel : variabelvariabel
# ulang : ulang
# nasabah : nasabah
# bri : bri
# internet : internet
# banking : banking
# dimana : mana
# kota : kota
# diambil : ambil
# manfaat : manfaat
# kemudahan : mudah
# keamanan : aman
# ketersediaan : sedia
# fitur : fitur
# kecuali : kecuali
# pln : pln
# badan : badan
# milik : milik
# negara : negara
# bergerak : gerak
# penyediaan : sedia
# listrik : listrik
# nasional : nasional
# mengelola : kelola
# bisnisnya : bisnis
# praktekpaktek : praktekpaktek
# terbaik : baik
# mengoptimalisasikan : optimalisasi
# sumbr : sumbr
# dimiliki : milik
# karir : karir
# semangat : semangat
# karyawan : karyawan
# cabang : cabang
# bersifat : sifat
# respondenuji : respondenuji
# reliabilitas : reliabilitas
# kesetiaan : setia
# orgnisasional : orgnisasional
# mentor : mentor
# sponsor : sponsor
# kesempatan : sempat
# tumbuh : tumbuh
# diatas : atas
# kuat : kuat
# kerjakaryawan : kerjakaryawan
# depot : depot
# barokah : barokah
# prambon : prambon
# accidental : accidental
# independen : independen
# dependen : dependen
# haryono : haryono
# arifin : arifin
# perilaku : perilaku
# keputusan : putus
# honda : honda
# vario : vario
# dealler : dealler
# surya : surya
# agung : agung
# motor : motor
# dealer : dealer
# manakah : mana
# kebudayaan : budaya
# psikologis : psikologis
# dianalisa : dianalisa
# dijadikan : jadi
# bauran : baur
# eceran : ecer
# langkah : langkah
# pemasaran : pasar
# keberhasilan : hasil
# produksi : produksi
# barang : barang
# jasaindah : jasaindah
# bisnis : bisnis
# jual : jual
# memperhatikan : perhati
# mengambil : ambil
# teori : teori
# berman : man
# evans : evans
# foster : foster
# lokasi : lokasi
# promosi : promosi
# indah : indah
# respondenteknik : respondenteknik
# wawancara : wawancara
# kepustakaan : pustaka
# respondenuntuk : respondenuntuk
# klasiksedangkan : klasiksedangkan
# bangkalannamun : bangkalannamun
# bangakalanvariabel : bangakalanvariabel
# pemebelian : beli
# kuci : kuci
# toko : toko
# aththaariq : aththaariq
# kompetensi : kompetensi
# dosen : dosen
# drrm : drrm
# moch : moch
# wispandonosems : wispandonosems
# dr : dr
# muhammad : muhammad
# alkirom : alkirom
# wildansemsi : wildansemsi
# menganalisis : analis
# pedagogik : pedagogik
# profesional : profesional
# kepribadian : pribadi
# primer : primer
# tersertifikasi : sertifikasi
# judgmental : judgmental
# koefisiensi : koefisiensi
# dipengaruhi : pengaruh
# diteliti : teliti
# sisanya : sisa
# signifikansi : signifikansi
# beta : beta
# kepribadiandan : kepribadiandan
# mendeskripsikan : deskripsi
# inovasi : inovasi
# keunggulan : unggul
# bersaing : saing
# diterapkannya : terap
# optik : optik
# reza : reza
# kualitatif : kualitatif
# fenomenologi : fenomenologi
# observasi : observasi
# penggunaan : guna
# dokumen : dokumen
# reduction : reduction
# display : display
# conclusion : conclusion
# drawing : drawing
# verification : verification
# volume : volume
# omzet : omzet
# penjualan : jual
# peningkatan : tingkat
# ditawarkannya : tawar
# pangsa : pangsa
# pasarnya : pasar
# meluas : luas
# jawa : jawa
# timur : timur
# rumusan : rumus
# pelaporan : lapor
# biaya : biaya
# meminimalkan : minimal
# risiko : risiko
# cacat : cacat
# cv : cv
# kapuas : kapuas
# inti : inti
# sarana : sarana
# profitabilitas : profitabilitas
# menggambarkan : gambar
# fenomena : fenomena
# berasal : asal
# periodik : periodik
# terperinci : perinci
# mengurangi : kurang
# berkurang : kurang
# meningkatnya : tingkat
# retailing : retailing
# mix : mix
# merchandise : merchandise
# atmosfer : atmosfer
# gerai : gerai
# retailimg : retailimg
# idola : idola
# mart : mart
# kwanyar : kwanyar
# berlandaskan : landas
# filsafat : filsafat
# positivisme : positivisme
# ditetapkan : tetap
# adjusted : adjusted
# besarnya : besar
# {'abstrak': 'abstrak', 'penelitian': 'teliti', 'metode': 'metode', 'kuantitatif': 'kuantitatif', 'menekankan': 'tekan', 'pengujian': 'uji', 'hipotesis': 'hipotesis', 'variabel': 'variabel', 'kepemimpinanx': 'kepemimpinanx', 'kompensasi': 'kompensasi', 'dilaksanakan': 'laksana', 'kantor': 'kantor', 'dinas': 'dinas', 'pendidikan': 'didik', 'kabupaten': 'kabupaten', 'sampang': 'sampang', 'sampel': 'sampel', 'orang': 'orang', 'pegawai': 'pegawai', 'negeri': 'negeri', 'sipil': 'sipil', 'non': 'non', 'pns': 'pns', 'bebas': 'bebas', 'bersamasama': 'bersamasama', 'hubungan': 'hubung', 'signifikan': 'signifikan', 'simultan': 'simultan', 'kepemimpinan': 'pimpin', 'kinerja': 'kerja', 'terbukti': 'bukti', 'nilai': 'nilai', 'fhitung': 'fhitung', 'tingkat': 'tingkat', 'pengaruh': 'pengaruh', 'dominan': 'dominan', 'hitung': 'hitung', 'positif': 'positif', 'parsial': 'parsial', 'terikat': 'ikat', 'kesimpulan': 'simpul', 'berdasarkan': 'dasar', 'statistik': 'statistik', 'memiliki': 'milik', 'membuktikan': 'bukti', 'berpengaruh': 'pengaruh', 'kunci': 'kunci', 'aplikasi': 'aplikasi', 'nyata': 'nyata', 'pemanfaatan': 'manfaat', 'teknologi': 'teknologi', 'informasi': 'informasi', 'komunikasi': 'komunikasi', 'bidang': 'bidang', 'layanan': 'layan', 'administrasi': 'administrasi', 'akademik': 'akademik', 'perguruan': 'guru', 'salah': 'salah', 'satunya': 'satu', 'sistem': 'sistem', 'portal': 'portal', 'universitas': 'universitas', 'trunojoyo': 'trunojoyo', 'madura': 'madura', 'implementasi': 'implementasi', 'proses': 'proses', 'penyelenggaraannya': 'selenggara', 'menemui': 'temu', 'kendala': 'kendala', 'teknis': 'teknis', 'bertujuan': 'tuju', 'kepuasan': 'puas', 'pelanggan': 'langgan', 'analisis': 'analisis', 'indeks': 'indeks', 'ditinjau': 'tinjau', 'webqual': 'webqual', 'fokus': 'fokus', 'perbaikan': 'baik', 'mutu': 'mutu', 'pelayanan': 'layan', 'website': 'website', 'trunjoyo': 'trunjoyo', 'importance': 'importance', 'performance': 'performance', 'analysis': 'analysis', 'kuantitaif': 'kuantitaif', 'deskriptif': 'deskriptif', 'gambaran': 'gambar', 'deskripsi': 'deskripsi', 'lukisan': 'lukis', 'sistematis': 'sistematis', 'faktual': 'faktual', 'akurat': 'akurat', 'kualitas': 'kualitas', 'jasa': 'jasa', 'online': 'online', 'mahasiswasampelpenelitianiniadalahmahasiswaangkatan': 'mahasiswasampelpenelitianiniadalahmahasiswaangkatan', 'teknik': 'teknik', 'stratified': 'stratified', 'random': 'random', 'sampling': 'sampling', 'alat': 'alat', 'kepentingan': 'penting', 'hasil': 'hasil', 'skor': 'skor', 'ikp': 'ikp', 'masuk': 'masuk', 'kategori': 'kategori', 'puas': 'puas', 'diagram': 'diagram', 'kartesius': 'kartesius', 'atribut': 'atribut', 'prioritas': 'prioritas', 'utama': 'utama', 'situs': 'situs', 'mahasiswa': 'mahasiswa', 'jelasdetail': 'jelasdetail', 'ter': 'ter', 'update': 'update', 'ki': 'ki', 'disitus': 'situs', 'utm': 'utm', 'dipercaya': 'percaya', 'pengguna': 'guna', 'aman': 'aman', 'data': 'data', 'krs': 'krs', 'khs': 'khs', 'transkrip': 'transkrip', 'personal': 'personal', 'sesuai': 'sesuai', 'kip': 'kip', 'tujuan': 'tuju', 'persepsi': 'persepsi', 'brand': 'brand', 'association': 'association', 'pakaian': 'pakai', 'kiddrock': 'kiddrock', 'studi': 'studi', 'distro': 'distro', 'cranberries': 'cranberries', 'pamekasan': 'pamekasan', 'survei': 'survei', 'populasi': 'populasi', 'responden': 'responden', 'desember': 'desember', 'pengambilan': 'ambil', 'aksidental': 'aksidental', 'pengumpulan': 'kumpul', 'lapangan': 'lapang', 'field': 'field', 'research': 'research', 'membagikan': 'bagi', 'kuesioner': 'kuesioner', 'riset': 'riset', 'perpustakaan': 'pustaka', 'pengolahan': 'olah', 'pengolaha': 'pengolaha', 'bantuan': 'bantu', 'perangkat': 'perangkat', 'lunak': 'lunak', 'spss': 'spss', 'versi': 'versi', 'uji': 'uji', 'validitas': 'validitas', 'reabilitas': 'reabilitas', 'skala': 'skala', 'likert': 'likert', 'konsumen': 'konsumen', 'dimensi': 'dimensi', 'jaminan': 'jamin', 'identifikasi': 'identifikasi', 'pribadi': 'pribadi', 'sosial': 'sosial', 'status': ...
# ------------------------
# Pandas Apply:   0%|          | 0/19 [00:00<?, ?it/s]
# 0     [abstrak, teliti, metode, kuantitatif, tekan, ...
# 1     [aplikasi, nyata, manfaat, teknologi, informas...
# 2     [tuju, teliti, persepsi, brand, association, l...
# 3     [abstrak, tuju, teliti, pengaruh, variabel, cu...
# 4     [abstrak, satiyah, pengaruh, faktorfaktor, lat...
# 5     [hasil, teliti, hitung, credit, risk, ratio, t...
# 6     [ali, rahbini, pengaruh, harga, kualitas, laya...
# 7     [abstrak, teliti, tuju, ukur, efektivitas, ikl...
# 8     [abstrak, dharma, abidin, syahkesimpulan, peng...
# 9     [tuju, teliti, pengaruh, celebrity, endorser, ...
# 10    [tuju, teliti, identifikasi, variabelvariabel,...
# 11    [pln, badan, usaha, milik, negara, gerak, bida...
# 12    [abstrak, tuju, teliti, identifikasi, variabel...
# 13    [abstrak, haryono, arifin, pengaruh, perilaku,...
# 14    [baur, ecer, salah, langkah, pasar, hasil, usa...
# 15    [abstrak, aththaariq, pengaruh, kompetensi, do...
# 16    [abstrak, tuju, teliti, deskripsi, inovasi, un...
# 17    [abstrak, teliti, rumus, lapor, biaya, kualita...
# 18    [tuju, teliti, pengaruh, variabel, retailing, ...
# Name: abstrak_stem, dtype: object

# %%
dataPTA.head()
# Out:
#                                                judul  \
# 0  PENGARUH KEPEMIMPINAN DAN KOMPENSASI TERHADAP ...
# 1  Pengukuran Website Quality Pada Situs Sistem A...
# 2  ANALISIS PERSEPSI BRAND ASSOCIATION MENURUT PE...
# 3  analisis faktor-faktor yang berpengaruh terhad...
# 4  PENGARUH FAKTOR-FAKTOR PELATIHAN DAN PENGEMBAN...
#
#                              penulis  \
# 0  Penulis : Hendri Wahyudi Prayitno
# 1   Penulis : Muhammad Zakaria Utomo
# 2                  Penulis : Faishal
# 3                  Penulis : Jailani
# 4                  Penulis : SATIYAH
#
#                                            abstraksi  \
# 0  abstrak penelitian ini menggunakan metode kuan...
# 1  aplikasi nyata pemanfaatan teknologi informasi...
# 2  tujuan penelitian ini adalah untuk mengetahui ...
# 3  abstrak tujuan penelitian ini adalah untuk men...
# 4  abstrak satiyah pengaruh faktorfaktor pelatiha...
#
#                                        abstrak_token  \
# 0  [abstrak, penelitian, ini, menggunakan, metode...
# 1  [aplikasi, nyata, pemanfaatan, teknologi, info...
# 2  [tujuan, penelitian, ini, adalah, untuk, menge...
# 3  [abstrak, tujuan, penelitian, ini, adalah, unt...
# 4  [abstrak, satiyah, pengaruh, faktorfaktor, pel...
#
#                                         abstrak_stop  \
# 0  [abstrak, penelitian, metode, kuantitatif, men...
# 1  [aplikasi, nyata, pemanfaatan, teknologi, info...
# 2  [tujuan, penelitian, persepsi, brand, associat...
# 3  [abstrak, tujuan, penelitian, pengaruh, variab...
# 4  [abstrak, satiyah, pengaruh, faktorfaktor, pel...
#
#                                         abstrak_stem   cluster        x0  \
# 0  [abstrak, teliti, metode, kuantitatif, tekan, ...      tech  0.381423
# 1  [aplikasi, nyata, manfaat, teknologi, informas...  religion -0.372050
# 2  [tuju, teliti, persepsi, brand, association, l...  religion -0.356188
# 3  [abstrak, tuju, teliti, pengaruh, variabel, cu...  religion -0.030234
# 4  [abstrak, satiyah, pengaruh, faktorfaktor, lat...      tech  0.139304
#
#          x1
# 0  0.269279
# 1  0.213274
# 2 -0.158817
# 3  0.108835
# 4 -0.114255

# %% [markdown]
# # TF Process

# %%
# initialize the vectorizer
vectorizer = TfidfVectorizer(sublinear_tf=True, min_df=5, max_df=0.95)
# fit_transform applies TF-IDF to clean texts - we save the array of vectors in X
X = vectorizer.fit_transform(dataPTA['abstraksi'])
print (X)
# Out:
#   (0, 29)	0.06474595268799721
#   (0, 25)	0.06157899159182178
#   (0, 10)	0.07946657266020872
#   (0, 37)	0.10534671047030739
#   (0, 8)	0.1200673304425189
#   (0, 36)	0.08380741095766932
#   (0, 41)	0.08380741095766932
#   (0, 63)	0.12909663127382148
#   (0, 21)	0.20329166201611018
#   (0, 46)	0.15035515404765964
#   (0, 55)	0.1679183282588988
#   (0, 39)	0.2519747751342448
#   (0, 17)	0.1292304284783874
#   (0, 65)	0.15450290180470297
#   (0, 3)	0.21857959726105772
#   (0, 60)	0.13454860344839442
#   (0, 59)	0.1964144176973602
#   (0, 33)	0.20329166201611018
#   (0, 56)	0.1799870847361448
#   (0, 7)	0.2519747751342448
#   (0, 4)	0.17768701009837007
#   (0, 15)	0.07542534888766894
#   (0, 64)	0.09917526969118305
#   (0, 54)	0.1200673304425189
#   (0, 52)	0.0935925224291978
#   :	:
#   (18, 46)	0.10273656840224867
#   (18, 55)	0.08399387650931331
#   (18, 39)	0.10168785582731239
#   (18, 17)	0.05215270128770165
#   (18, 65)	0.15308578259336206
#   (18, 60)	0.06730211585432516
#   (18, 59)	0.13420852372347913
#   (18, 56)	0.10815740897677151
#   (18, 7)	0.10168785582731239
#   (18, 4)	0.09764447140397521
#   (18, 15)	0.10815740897677151
#   (18, 64)	0.14221399519604405
#   (18, 52)	0.13420852372347913
#   (18, 1)	0.1698918101218949
#   (18, 19)	0.15728940412038844
#   (18, 70)	0.22261412244288156
#   (18, 23)	0.16095668708897942
#   (18, 47)	0.0950636122701093
#   (18, 40)	0.1210278054747227
#   (18, 72)	0.1897866698802458
#   (18, 27)	0.08922061535560448
#   (18, 38)	0.07926571609627857
#   (18, 35)	0.09764447140397521
#   (18, 24)	0.12445169700001252
#   (18, 44)	0.1536371720240904

# %%
from sklearn.cluster import KMeans

# initialize kmeans with 3 centroids
kmeans = KMeans(n_clusters=3, random_state=42)
# fit the model
kmeans.fit(X)
# store cluster labels in a variable
clusters = kmeans.labels_

# %%
from sklearn.decomposition import PCA

# initialize PCA with 2 components
pca = PCA(n_components=2, random_state=42)
# pass our X to the pca and store the reduced vectors into pca_vecs
pca_vecs = pca.fit_transform(X.toarray())
# save our two dimensions into x0 and x1
x0 = pca_vecs[:, 0]
x1 = pca_vecs[:, 1]

# %%
# assign clusters and pca vectors to our dataframe 
dataPTA['cluster'] = clusters
dataPTA['x0'] = x0
dataPTA['x1'] = x1

# %%
def get_top_keywords(n_terms):
    """This function returns the keywords for each centroid of the KMeans"""
    df = pd.DataFrame(X.todense()).groupby(clusters).mean() # groups the TF-IDF vector by cluster
    terms = vectorizer.get_feature_names_out() # access tf-idf terms
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([terms[t] for t in np.argsort(r)[-n_terms:]])) # for each row of the dataframe, find the n terms that have the highest tf idf score
            
get_top_keywords(10)
# Out:
# Cluster 0
# variabel,berpengaruh,adalah,metode,yang,ini,penelitian,pada,dapat,produk
#
# Cluster 1
# dengan,konsumen,signifikan,penelitian,bangkalan,pengaruh,secara,terhadap,yang,variabel
#
# Cluster 2
# sedangkan,berdasarkan,pada,dalam,adalah,data,sebesar,ini,yang,penelitian

# %%
# map clusters to appropriate labels 
cluster_map = {0: "sport", 1: "tech", 2: "religion"}
# apply mapping
dataPTA['cluster'] = dataPTA['cluster'].map(cluster_map)
print (x0)
print (x1)
# Out:
# [ 0.38142314 -0.37204966 -0.3561882  -0.03023387  0.1393039  -0.29686001
#   0.30693741  0.22354957  0.57962989 -0.11211581  0.1340585   0.07480033
#   0.1411906   0.13099208 -0.14067548 -0.00663473 -0.4889322  -0.28575775
#  -0.02243769]
# [ 0.26927912  0.21327414 -0.1588169   0.10883487 -0.11425457  0.64000427
#  -0.2559785   0.0464178   0.37226718 -0.24422655 -0.10065011 -0.06319726
#  -0.20692187 -0.35895598 -0.32498436  0.22445859 -0.00827304  0.00141727
#  -0.0396941 ]

# %%
# set image size
plt.figure(figsize=(12, 7))
# set a title
plt.title("TF-IDF + KMeans 20newsgroup clustering", fontdict={"fontsize": 18})
# set axes names
plt.xlabel("X0", fontdict={"fontsize": 16})
plt.ylabel("X1", fontdict={"fontsize": 16})
# create scatter plot with seaborn, where hue is the class used to group the data
sns.scatterplot(data=dataPTA, x='x0', y='x1', hue='cluster', palette="viridis")
plt.show()
